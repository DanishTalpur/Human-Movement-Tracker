# %%
# !pip install roboflow
import os
from roboflow import Roboflow
api_key = os.getenv("ROBOFLOW_API_KEY", "")
if not api_key:
    raise RuntimeError("ROBOFLOW_API_KEY not set. Create a .env with your key or set env var.")
rf = Roboflow(api_key=api_key)
project = rf.workspace("leo-ueno").project("people-detection-o4rdr")
version = project.version(10)
dataset = version.download("yolov8")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.7/88.7 kB 5.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 6.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.9/49.9 MB 20.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 87.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 116.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.12.0.88
#     Uninstalling opencv-python-headless-4.12.0.88:
#       Successfully uninstalled opencv-python-headless-4.12.0.88
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to People-Detection-10 in yolov8:: 100%|██████████| 34814/34814 [00:13<00:00, 2580.65it/s]

# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.1 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
model= YOLO("yolov8n.pt")
model.train(data=f"{dataset.location}/data.yaml", epochs=20, imgsz=640, batch=10, cache=False)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# Ultralytics 8.3.203 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# !cp model.zip /content/drive/MyDrive/
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# cp: cannot stat 'model.zip': No such file or directory

# %%
# !zip -r model.zip runs
# Out:
#   adding: runs/ (stored 0%)
#   adding: runs/detect/ (stored 0%)
#   adding: runs/detect/train/ (stored 0%)
#   adding: runs/detect/train/labels.jpg (deflated 31%)
#   adding: runs/detect/train/train_batch15210.jpg (deflated 11%)
#   adding: runs/detect/train/val_batch0_labels.jpg (deflated 7%)
#   adding: runs/detect/train/val_batch2_labels.jpg (deflated 8%)
#   adding: runs/detect/train/train_batch0.jpg (deflated 8%)
#   adding: runs/detect/train/BoxP_curve.png (deflated 17%)
#   adding: runs/detect/train/confusion_matrix.png (deflated 34%)
#   adding: runs/detect/train/train_batch1.jpg (deflated 6%)
#   adding: runs/detect/train/args.yaml (deflated 53%)
#   adding: runs/detect/train/BoxR_curve.png (deflated 19%)
#   adding: runs/detect/train/val_batch1_labels.jpg (deflated 6%)
#   adding: runs/detect/train/BoxPR_curve.png (deflated 18%)
#   adding: runs/detect/train/train_batch15211.jpg (deflated 17%)
#   adding: runs/detect/train/val_batch2_pred.jpg (deflated 8%)
# ...

# %%
from google.colab import files
files.download("model.zip")
